# %%
from datetime import datetime

# %%
CURRENT_TIME_STAMP = f"{datetime.now().strftime('%Y-%m-%d__%H:%M:%S')}"
print(CURRENT_TIME_STAMP)
# Out:
# 2026-04-01__11:33:56

# %%
#model = {}
keys = ['models', 'r2_score', 'overfit_gap', 'rmse', 'cval_r2_score_std']

"""
models = {
            'models' : {'linear_reg' : linear model, ...},
            'r2_score' : {'linear_reg' : .., ...},
            'overfit_gap' : {...},
            'rmse' : ..., 
            'cval_r2_score_std' : ...
            }
"""
model = dict.fromkeys(keys, {})
print(model)
# Out:
# {'models': {}, 'r2_score': {}, 'overfit_gap': {}, 'rmse': {}, 'cval_r2_score_std': {}}

# %%
trained_models = {
            'models' : {'linear_reg' : 'linear model', 'random_forest' : 'rd model', 'xg_boost' : 'xg model'},
            'r2_score' : {'linear_reg' : 0.8, 'random_forest' : 0.9, 'xg_boost' : 0.7},
            'overfit_gap' : {'linear_reg' : 0.02, 'random_forest' : 0.05, 'xg_boost' : 0.01},
            'cval_r2_score_std' : {'linear_reg' : 0.012, 'random_forest' : 0.015, 'xg_boost' : 0.01}
            }

# %%
# model_r2_score, model_overfit_gap
base_r2_score = 0.6
base_overfit_gap = 0.1

for model_name, r2_score in trained_models['r2_score'].items():
    
    print(f"model name : {model_name} \nr2_score : {r2_score}\n------------------------")
# Out:
# model name : linear_reg
# r2_score : 0.8
# ------------------------
# model name : random_forest
# r2_score : 0.9
# ------------------------
# model name : xg_boost
# r2_score : 0.7
# ------------------------
